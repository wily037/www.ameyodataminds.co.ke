# %% [markdown]
# <a href="https://colab.research.google.com/github/wily037/www.ameyodataminds.co.ke/blob/main/A_DATA_DRIVEN_ANALYSIS_OF_STUDENT_PERFORMANCE_AT_THE_COUNTY_LEVEL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
importimportimportimport pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data={'Names':['Wilfred', 'John', 'James','Nancy', 'Elizabeth', 'William', 'Joseph', 'Jabez','Leah', 'Millicent'],
'Sex':['Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Female', 'Female']
,'Age':[23,22,24,21,25,20,22,25,21,24]
,'County':['Busia','Kisumu','Kakamega','Kisii','Kercho', 'Nyeri', 'Mombasa', 'Nakuru','Meru','Nairobi']
, 'Scores':[78,60,89,56,67,40,64,78,80,73]
, 'Study hours':[3,4.5,6,5,2,5.5,4.2,3,7,3]
,'Attendance rate':[86,80,76,66,81,76,70,65,75,56]
, 'Previous scores':[56,68,78,70,54,75,66,45,67,72]}
df=pd.DataFrame(data)
display(df)
df.dtypes
df.shape
df.describe()
df.nlargest(1, 'Scores')
df.nlargest(5, 'Scores')
df.nsmallest(1, 'Scores')
df.nsmallest(6, 'Scores')
# Out:
#        Names     Sex  Age    County  Scores  Study hours  Attendance rate  \
# 0    Wilfred    Male   23     Busia      78          3.0               86
# 1       John    Male   22    Kisumu      60          4.5               80
# 2      James    Male   24  Kakamega      89          6.0               76
# 3      Nancy  Female   21     Kisii      56          5.0               66
# 4  Elizabeth  Female   25    Kercho      67          2.0               81
# 5    William    Male   20     Nyeri      40          5.5               76
# 6     Joseph    Male   22   Mombasa      64          4.2               70
# 7      Jabez    Male   25    Nakuru      78          3.0               65
# 8       Leah  Female   21      Meru      80          7.0               75
# 9  Millicent  Female   24   Nairobi      73          3.0               56
#
#    Previous scores
# 0               56
# 1               68
# 2               78
# 3               70
# 4               54
# 5               75
# ...

# %% [markdown]
# # New Section
