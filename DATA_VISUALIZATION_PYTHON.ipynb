# %% [markdown]
# <a href="https://colab.research.google.com/github/wily037/www.ameyodataminds.co.ke/blob/main/DATA_VISUALIZATION_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
n=10
X=np.random.rand(n)
Y=np.random.rand(n)
#line plot
#plt.plot(X,Y)
#plt.show()
#Bar plot
plt.bar(X,Y)
plt.show()
#scatter plot
plt.scatter(X,Y , color='red')
plt.show()
# plotting a pie chart
X=np.array([34,50,30,45,28])
plt.pie(X)
plt.show()
# Visualizing the data in data frames
Data=pd.DataFrame(np.random.rand(20,5), columns=['A','B','C','D','E'])
#print(Data)
display(Data)
#plotting
Data.plot.bar()
plt.show()
#plotting a stacked bar graph
Data.plot.bar(stacked=True)
plt.show()
#Plotting a histogram
Data.plot.hist()
plt.show()
#plotting a stacked HistogramData.plot.hist(stacked=True)plt.show()
# Out:
#            A         B         C         D         E
# 0   0.937660  0.753533  0.204564  0.427138  0.822275
# 1   0.452042  0.054030  0.924448  0.199377  0.925262
# 2   0.592767  0.427055  0.663007  0.969607  0.350362
# 3   0.134201  0.483107  0.114049  0.498277  0.496226
# 4   0.321278  0.771894  0.162574  0.442502  0.201753
# 5   0.494960  0.839443  0.225210  0.781813  0.850848
# 6   0.262605  0.394373  0.189477  0.818521  0.627948
# 7   0.508985  0.948753  0.095994  0.832745  0.496201
# 8   0.834169  0.271314  0.514286  0.454957  0.177074
# 9   0.971585  0.429559  0.887310  0.496641  0.194229
# 10  0.581161  0.388420  0.466704  0.791132  0.600044
# 11  0.270444  0.307781  0.910676  0.703779  0.305190
# 12  0.462418  0.710500  0.298181  0.557199  0.305857
# 13  0.141203  0.347951  0.402638  0.075247  0.899185
# 14  0.211243  0.142503  0.714383  0.932712  0.431996
# 15  0.177327  0.129225  0.471674  0.537340  0.820933
# 16  0.847269  0.436722  0.189690  0.140723  0.028447
# ...
